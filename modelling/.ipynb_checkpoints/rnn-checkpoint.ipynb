# %%
import numpy as np
from pickle import dump, load
from numpy import array
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout, Bidirectional, Conv1D, MaxPooling1D, Flatten
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.callbacks import EarlyStopping
import tensorflow.keras.optimizers as optimizers
from tensorflow.keras.utils import plot_model, model_to_dot
import tensorflow as tf
from os import listdir
import lightkurve as lk
import pickle
import pandas as pd
from collections import Counter
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

def build_rnn(X,lstm_layers,cells,output_size):
    model = Sequential()
    
    #model.add(Dense(units=cells,input_shape=(X.shape[1], X.shape[2])))
    for i in range(lstm_layers - 1):
        model.add(Bidirectional(LSTM(cells,activation='sigmoid',return_sequences=True)))
        model.add(Dropout(0.2))
        
    model.add(Bidirectional(LSTM(cells,activation='sigmoid')))
    model.add(Dropout(0.2))
    
    model.add(Dense(output_size, activation='softmax'))

    opt = Adam(learning_rate=0.0008)
    model.compile(loss = "categorical_hinge", metrics=['categorical_accuracy'], optimizer = opt)
    return model

def build_cnn(X):
    model = Sequential()
    
    model.add(Conv1D(filters=380, kernel_size=8, activation='relu', input_shape=(760, 1)))
    model.add(MaxPooling1D(pool_size=2))
    
    model.add(Conv1D(filters=190, kernel_size=8, activation='relu', input_shape=(760, 1)))
    model.add(MaxPooling1D(pool_size=2))
    
    model.add(Conv1D(filters=95, kernel_size=8, activation='relu', input_shape=(760, 1)))
    model.add(MaxPooling1D(pool_size=2))
    
    model.add(Conv1D(filters=47, kernel_size=16, activation='relu', input_shape=(760, 1)))
    model.add(MaxPooling1D(pool_size=2))
    
    model.add(Conv1D(filters=24, kernel_size=32, activation='relu', input_shape=(760, 1)))
    model.add(MaxPooling1D(pool_size=2))
    
    model.add(Flatten())
    model.add(Dense(20,activation='relu'))
    model.add(Dense(10,activation='relu'))
    model.add(Dense(2,activation='softmax'))

    opt = optimizers.Adam(learning_rate=3e-5)
    model.compile(loss = "categorical_hinge", metrics=['categorical_accuracy'], optimizer = opt)
    return model

x = np.load('E:/x_m.npy')
y = np.load('E:/y_m.npy')
print(y[0])
# Out:
# [0. 1.]

# %%
model = build_rnn(x,lstm_layers=2,cells=12,output_size=2)

history = model.fit(x, y, epochs=10, verbose=1,batch_size=16, validation_split=0.2, shuffle=True)
#model.save(str('bot3.h5'))

# %%
y_pred = model.predict(x, verbose=0)
print(y_pred)

# %%
model = build_cnn(x)
model.summary()

history = model.fit(x, y, epochs=60, verbose=1, batch_size=16, validation_split=0.1, shuffle=True)
#model.save(str('bot3.h5'))
# Out:
# Model: "sequential_36"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_67 (Conv1D)           (None, 753, 380)          3420
# _________________________________________________________________
# max_pooling1d_67 (MaxPooling (None, 376, 380)          0
# _________________________________________________________________
# conv1d_68 (Conv1D)           (None, 369, 190)          577790
# _________________________________________________________________
# max_pooling1d_68 (MaxPooling (None, 184, 190)          0
# _________________________________________________________________
# conv1d_69 (Conv1D)           (None, 177, 95)           144495
# _________________________________________________________________
# max_pooling1d_69 (MaxPooling (None, 88, 95)            0
# _________________________________________________________________
# conv1d_70 (Conv1D)           (None, 73, 47)            71487
# _________________________________________________________________
# max_pooling1d_70 (MaxPooling (None, 36, 47)            0
# _________________________________________________________________
# conv1d_71 (Conv1D)           (None, 5, 24)             36120
# _________________________________________________________________
# max_pooling1d_71 (MaxPooling (None, 2, 24)             0
# _________________________________________________________________
# flatten_26 (Flatten)         (None, 48)                0
# _________________________________________________________________
# dense_51 (Dense)             (None, 20)                980
# _________________________________________________________________
# dense_52 (Dense)             (None, 10)                210
# _________________________________________________________________
# dense_53 (Dense)             (None, 2)                 22
# =================================================================
# Total params: 834,524
# Trainable params: 834,524
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/60
# 134/134 [==============================] - 2s 15ms/step - loss: 1.0043 - categorical_accuracy: 0.5124 - val_loss: 0.9969 - val_categorical_accuracy: 0.5188
# Epoch 2/60
# 134/134 [==============================] - 2s 13ms/step - loss: 0.9975 - categorical_accuracy: 0.5096 - val_loss: 0.9852 - val_categorical_accuracy: 0.5314
# Epoch 3/60
# 134/134 [==============================] - 2s 13ms/step - loss: 0.9915 - categorical_accuracy: 0.5390 - val_loss: 0.9829 - val_categorical_accuracy: 0.5649
# Epoch 4/60
# 134/134 [==============================] - 2s 13ms/step - loss: 0.9831 - categorical_accuracy: 0.5413 - val_loss: 0.9707 - val_categorical_accuracy: 0.5983
# Epoch 5/60
# 134/134 [==============================] - 2s 12ms/step - loss: 0.9838 - categorical_accuracy: 0.5492 - val_loss: 0.9810 - val_categorical_accuracy: 0.5983
# Epoch 6/60
# 134/134 [==============================] - 2s 13ms/step - loss: 0.9627 - categorical_accuracy: 0.5758 - val_loss: 0.9665 - val_categorical_accuracy: 0.5774
# Epoch 7/60
# 134/134 [==============================] - 2s 13ms/step - loss: 0.9421 - categorical_accuracy: 0.5898 - val_loss: 0.9677 - val_categorical_accuracy: 0.5690
# Epoch 8/60
# 134/134 [==============================] - 2s 12ms/step - loss: 0.9295 - categorical_accuracy: 0.6136 - val_loss: 0.9510 - val_categorical_accuracy: 0.5607
# Epoch 9/60
# 134/134 [==============================] - 2s 12ms/step - loss: 0.9020 - categorical_accuracy: 0.6253 - val_loss: 0.9311 - val_categorical_accuracy: 0.5941
# Epoch 10/60
# 134/134 [==============================] - 2s 13ms/step - loss: 0.8848 - categorical_accuracy: 0.6169 - val_loss: 0.9260 - val_categorical_accuracy: 0.5941
# Epoch 11/60
# 134/134 [==============================] - 2s 12ms/step - loss: 0.8605 - categorical_accuracy: 0.6304 - val_loss: 0.9325 - val_categorical_accuracy: 0.5607
# Epoch 12/60
# 134/134 [==============================] - 2s 12ms/step - loss: 0.8405 - categorical_accuracy: 0.6281 - val_loss: 0.9170 - val_categorical_accuracy: 0.5690
# Epoch 13/60
# 134/134 [==============================] - 2s 13ms/step - loss: 0.8222 - categorical_accuracy: 0.6290 - val_loss: 0.8914 - val_categorical_accuracy: 0.5774
# Epoch 14/60
# 134/134 [==============================] - 2s 12ms/step - loss: 0.7938 - categorical_accuracy: 0.6309 - val_loss: 0.9020 - val_categorical_accuracy: 0.5690
# Epoch 15/60
# 134/134 [==============================] - 2s 12ms/step - loss: 0.7908 - categorical_accuracy: 0.6323 - val_loss: 0.8904 - val_categorical_accuracy: 0.5690
# Epoch 16/60
# 134/134 [==============================] - 2s 12ms/step - loss: 0.7669 - categorical_accuracy: 0.6407 - val_loss: 0.8449 - val_categorical_accuracy: 0.5900
# Epoch 17/60
# 134/134 [==============================] - 2s 12ms/step - loss: 0.7548 - categorical_accuracy: 0.6374 - val_loss: 0.8619 - val_categorical_accuracy: 0.5900
# Epoch 18/60
# 134/134 [==============================] - 2s 12ms/step - loss: 0.7529 - categorical_accuracy: 0.6402 - val_loss: 0.9047 - val_categorical_accuracy: 0.5397
# Epoch 19/60
# 134/134 [==============================] - 2s 12ms/step - loss: 0.7426 - categorical_accuracy: 0.6398 - val_loss: 0.8420 - val_categorical_accuracy: 0.5732
# Epoch 20/60
# 134/134 [==============================] - 2s 12ms/step - loss: 0.7300 - categorical_accuracy: 0.6440 - val_loss: 0.8515 - val_categorical_accuracy: 0.5816
# Epoch 21/60
# 134/134 [==============================] - 2s 12ms/step - loss: 0.7180 - categorical_accuracy: 0.6542 - val_loss: 0.8672 - val_categorical_accuracy: 0.5649
# Epoch 22/60
# 134/134 [==============================] - 2s 13ms/step - loss: 0.7218 - categorical_accuracy: 0.6444 - val_loss: 0.8978 - val_categorical_accuracy: 0.5565
# Epoch 23/60
# 134/134 [==============================] - 2s 12ms/step - loss: 0.7135 - categorical_accuracy: 0.6519 - val_loss: 0.8603 - val_categorical_accuracy: 0.5732
# Epoch 24/60
# 134/134 [==============================] - 2s 13ms/step - loss: 0.7019 - categorical_accuracy: 0.6514 - val_loss: 0.8723 - val_categorical_accuracy: 0.5607
# Epoch 25/60
# 134/134 [==============================] - 2s 13ms/step - loss: 0.7019 - categorical_accuracy: 0.6575 - val_loss: 0.8781 - val_categorical_accuracy: 0.5690
# Epoch 26/60
# 134/134 [==============================] - 2s 13ms/step - loss: 0.6950 - categorical_accuracy: 0.6584 - val_loss: 0.8460 - val_categorical_accuracy: 0.5690
# Epoch 27/60
# 134/134 [==============================] - 2s 13ms/step - loss: 0.6884 - categorical_accuracy: 0.6673 - val_loss: 0.8282 - val_categorical_accuracy: 0.5900
# Epoch 28/60
# 134/134 [==============================] - 2s 13ms/step - loss: 0.6988 - categorical_accuracy: 0.6547 - val_loss: 0.8513 - val_categorical_accuracy: 0.5816
# Epoch 29/60
# 134/134 [==============================] - 2s 13ms/step - loss: 0.6747 - categorical_accuracy: 0.6715 - val_loss: 0.8742 - val_categorical_accuracy: 0.5607
# Epoch 30/60
# 134/134 [==============================] - 2s 13ms/step - loss: 0.6705 - categorical_accuracy: 0.6743 - val_loss: 0.8441 - val_categorical_accuracy: 0.5732
# Epoch 31/60
# 134/134 [==============================] - 2s 13ms/step - loss: 0.6752 - categorical_accuracy: 0.6720 - val_loss: 0.8373 - val_categorical_accuracy: 0.5900
# Epoch 32/60
# 134/134 [==============================] - 2s 12ms/step - loss: 0.6681 - categorical_accuracy: 0.6715 - val_loss: 0.8522 - val_categorical_accuracy: 0.5690
# Epoch 33/60
# 134/134 [==============================] - 2s 13ms/step - loss: 0.6599 - categorical_accuracy: 0.6762 - val_loss: 0.8701 - val_categorical_accuracy: 0.5690
# Epoch 34/60
# 134/134 [==============================] - 2s 13ms/step - loss: 0.6552 - categorical_accuracy: 0.6804 - val_loss: 0.8216 - val_categorical_accuracy: 0.5858
# Epoch 35/60
# 134/134 [==============================] - 2s 12ms/step - loss: 0.6599 - categorical_accuracy: 0.6785 - val_loss: 0.8096 - val_categorical_accuracy: 0.6109
# Epoch 36/60
# 134/134 [==============================] - 2s 12ms/step - loss: 0.6646 - categorical_accuracy: 0.6748 - val_loss: 0.8644 - val_categorical_accuracy: 0.5774
# Epoch 37/60
# 134/134 [==============================] - 2s 13ms/step - loss: 0.6531 - categorical_accuracy: 0.6818 - val_loss: 0.8862 - val_categorical_accuracy: 0.5607
# Epoch 38/60
# 134/134 [==============================] - 2s 13ms/step - loss: 0.6446 - categorical_accuracy: 0.6864 - val_loss: 0.8677 - val_categorical_accuracy: 0.5607
# Epoch 39/60
# 134/134 [==============================] - 2s 13ms/step - loss: 0.6306 - categorical_accuracy: 0.6953 - val_loss: 0.8727 - val_categorical_accuracy: 0.5649
# Epoch 40/60
# 134/134 [==============================] - 2s 13ms/step - loss: 0.6229 - categorical_accuracy: 0.6986 - val_loss: 0.8718 - val_categorical_accuracy: 0.5607
# Epoch 41/60
# 134/134 [==============================] - 2s 13ms/step - loss: 0.6157 - categorical_accuracy: 0.7046 - val_loss: 0.8516 - val_categorical_accuracy: 0.5732
# Epoch 42/60
# 134/134 [==============================] - 2s 13ms/step - loss: 0.6186 - categorical_accuracy: 0.7037 - val_loss: 0.8564 - val_categorical_accuracy: 0.5774
# Epoch 43/60
# 134/134 [==============================] - 2s 13ms/step - loss: 0.6100 - categorical_accuracy: 0.7046 - val_loss: 0.8542 - val_categorical_accuracy: 0.5774
# Epoch 44/60
# 134/134 [==============================] - 2s 12ms/step - loss: 0.6225 - categorical_accuracy: 0.7023 - val_loss: 0.8820 - val_categorical_accuracy: 0.5523
# Epoch 45/60
# 134/134 [==============================] - 2s 12ms/step - loss: 0.6210 - categorical_accuracy: 0.6981 - val_loss: 0.8626 - val_categorical_accuracy: 0.5732
# Epoch 46/60
# 134/134 [==============================] - 2s 13ms/step - loss: 0.6061 - categorical_accuracy: 0.7098 - val_loss: 0.8768 - val_categorical_accuracy: 0.5649
# Epoch 47/60
# 134/134 [==============================] - 2s 13ms/step - loss: 0.5987 - categorical_accuracy: 0.7121 - val_loss: 0.9041 - val_categorical_accuracy: 0.5481
# Epoch 48/60
# 134/134 [==============================] - 2s 12ms/step - loss: 0.5955 - categorical_accuracy: 0.7130 - val_loss: 0.8928 - val_categorical_accuracy: 0.5397
# Epoch 49/60
# 134/134 [==============================] - 2s 13ms/step - loss: 0.5827 - categorical_accuracy: 0.7186 - val_loss: 0.8766 - val_categorical_accuracy: 0.5607
# Epoch 50/60
# 134/134 [==============================] - 2s 12ms/step - loss: 0.5922 - categorical_accuracy: 0.7116 - val_loss: 0.8699 - val_categorical_accuracy: 0.5690
# Epoch 51/60
# 134/134 [==============================] - 2s 13ms/step - loss: 0.5829 - categorical_accuracy: 0.7196 - val_loss: 0.8599 - val_categorical_accuracy: 0.5816
# Epoch 52/60
# 134/134 [==============================] - 2s 13ms/step - loss: 0.5842 - categorical_accuracy: 0.7177 - val_loss: 0.8548 - val_categorical_accuracy: 0.5774
# Epoch 53/60
# 134/134 [==============================] - 2s 13ms/step - loss: 0.5684 - categorical_accuracy: 0.7289 - val_loss: 0.8766 - val_categorical_accuracy: 0.5607
# Epoch 54/60
# 134/134 [==============================] - 2s 13ms/step - loss: 0.5618 - categorical_accuracy: 0.7303 - val_loss: 0.8587 - val_categorical_accuracy: 0.5774
# Epoch 55/60
# 134/134 [==============================] - 2s 13ms/step - loss: 0.5666 - categorical_accuracy: 0.7270 - val_loss: 0.8713 - val_categorical_accuracy: 0.5649
# Epoch 56/60
# 134/134 [==============================] - 2s 13ms/step - loss: 0.5547 - categorical_accuracy: 0.7368 - val_loss: 0.9161 - val_categorical_accuracy: 0.5439
# Epoch 57/60
# 134/134 [==============================] - ETA: 0s - loss: 0.5638 - categorical_accuracy: 0.7281 ETA:  - 2s 13ms/step - loss: 0.5647 - categorical_accuracy: 0.7275 - val_loss: 0.8561 - val_categorical_accuracy: 0.5900
# Epoch 58/60
# 134/134 [==============================] - 2s 13ms/step - loss: 0.5481 - categorical_accuracy: 0.7382 - val_loss: 0.8723 - val_categorical_accuracy: 0.5649
# Epoch 59/60
# 134/134 [==============================] - 2s 13ms/step - loss: 0.5387 - categorical_accuracy: 0.7420 - val_loss: 0.8710 - val_categorical_accuracy: 0.5649
# Epoch 60/60
# 134/134 [==============================] - 2s 12ms/step - loss: 0.5402 - categorical_accuracy: 0.7420 - val_loss: 0.8540 - val_categorical_accuracy: 0.5816

# %%
model.save(str('55bot.h5'))

# %%
plt.plot(history.history['categorical_accuracy'])
plt.plot(history.history['val_categorical_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('accuarcy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()

plt.figure()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('accuarcy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()

# %%
def unencode(matrix):
    new_matrix = np.zeros(matrix.shape[0])
    for i in range(matrix.shape[0]):
        val = np.argmax(matrix[i])
        new_matrix[i] = classes[val]
    return new_matrix

y_pred = model.predict(x, verbose=0)

classes = [0,1,2,3,4,5]
cm = confusion_matrix(unencode(y),unencode(y_pred),labels=classes)
plt.imshow(np.log(cm),cmap='Blues')
plt.xlabel('Predicted y-values')
plt.ylabel('Actual y-values')
plt.colorbar()
plt.show()

print(cm)

# %%
i = 76#86
b = 20
good = []
bad = []
values = pd.read_csv('E:/catalogues/final_quasar_catalogue.csv', sep=',', usecols=[i],header=0,squeeze=True).to_numpy()
print(pd.read_csv('E:/catalogues/final_quasar_catalogue.csv', sep=',', header=0,squeeze=True).columns[i])
pred = unencode(y_pred)
act = unencode(y)
for n in range(len(x)):
    value = values[n]
    if pred[n] == act[n]:
        good.append(value)
    else:
        bad.append(value)
        
print('bad:',np.mean(bad),'good:',np.mean(good))
plt.hist(good,bins=b,color='g',alpha=0.5)
plt.hist(bad,bins=b,color='r',alpha=0.5)
plt.show()

'''
REWE_CIII
BI_CIV
MI
VAR_CHI2 - bad results are way more variable

'''

# %%
from scipy.stats import ttest_1samp

good = []
bad = []
pred = unencode(y_pred)
act = unencode(y)
for n in range(len(x)):
    value = np.sum(np.abs(x[n,:,0]-1))
    if pred[n] == act[n]:
        good.append(value)
    else:
        bad.append(value)
        
print('bad:',np.mean(bad),'good:',np.mean(good))
plt.hist(good,bins=100,color='g',alpha=0.5)
plt.hist(bad,bins=100,color='r',alpha=0.5)
plt.show()

# %%
for cut in np.linspace(-28,-22,60):
    good_cut = [good[i] for i in range(len(good)) if good[i] < cut+0.2 and good[i]>cut]
    bad_cut = [bad[i] for i in range(len(bad)) if bad[i] < cut+0.2 and bad[i]>cut]
    plt.scatter(cut,len(good_cut)/(len(good_cut)+len(bad_cut)),c='b')

# %%
good_cut = [good[i] for i in range(len(good)) if good[i] > 0]
bad_cut = [bad[i] for i in range(len(bad)) if bad[i] > 0]
print(len(good_cut)/(len(good_cut)+len(bad_cut)))

# %%
values

# %%
import os
places = []
files = os.listdir('E:/sector_lightcurves/')
predictions = unencode(y_pred)
actual = unencode(y)
for n in range(len(predictions)):
    if predictions[n] == 4:
        if actual[n] == 4:
            places.append(files[n])

# %%
import lightkurve as lk
import pickle
import matplotlib.pyplot as plt

lc_dir = 'E:/sector_lightcurves/'

def load(file='1lc.pickle',width=18,height=3,dpi=1000,alpha=0.75,bin=True,bins=2000,sigma=20,save=False):
    plt.figure(figsize=(width, height), dpi=dpi)
    with open(file,'rb') as rfile:
        lc = pickle.load(rfile)
    lc.quality = np.zeros(len(lc.flux),dtype='int')
    if bin == True:
        lc = lc.remove_nans().remove_outliers(sigma=sigma).bin(bins=bins)
    elif bin == False:
        lc = lc.remove_nans().remove_outliers(sigma=sigma)
    plt.plot(lc.time,lc.flux,color='blue',alpha=alpha,label='TIC ' + str(lc.targetid))
    #plt.xlim(left=1340,right=1380)
    plt.xlabel("Time (BTJD Days)")
    plt.ylabel("Flux (e/s)")
    plt.title("Flux as a function of time for " + 'TIC ' + str(lc.targetid))
    if save == True:
        plt.savefig(str(file) + ".png")

# %%
def generate_data(data_path, data_amount, bins=1000):
    if data_amount == 'auto':
        data_amount = len(listdir(data_path))
    print("There are {0} lightcurves present in the data_path".format(data_amount))
    list_files = listdir(data_path)[0:data_amount]
    
    # generate lightcurve data
    X = np.zeros((0,bins,2))
    rows = []
    for file in list_files:
        with open(data_path + '/' + file, 'rb') as rfile:
            lc = pickle.load(rfile)
        if len(lc.flux)< bins:
            continue
        lc.quality = np.zeros(len(lc.flux),dtype='int')
        lc = lc.remove_outliers(sigma=20).remove_nans()
        flux = np.reshape(np.array([lc.time[:bins]]),(bins,1))
        flux_norm = (flux)/(np.max(flux)-np.min(flux))
        time = np.reshape(np.array([lc.flux[:bins]]),(bins,1))
        time_norm = (time - np.mean(time))/(np.max(time)-np.min(time))
        X_curve = np.array([np.concatenate((flux,time),axis=1)])

        X = np.concatenate((X,X_curve),axis=0)
        row = int(file.split('-')[0])
        rows.append(row)
    print('Generating lightcurve data complete')
    
    what_rows = []
    [what_rows.append(x) for x in rows if x not in what_rows]
    count_rows = Counter(rows)
    print('Objects identified')
    y = []
    ya = pd.read_csv('final_quasar_catalogue.csv', sep=',', usecols=['MASS'],header=0,squeeze=True).to_numpy()
    for r in what_rows:
        y_point = [ya[r]]
        y_list = []
        for x in range(0,count_rows[r]):
            y_list += y_point
        y += y_list
    print('Magnitudes created')
    
    y = 10**np.array(y)
    width = np.max(y)-np.min(y)
    mean = np.mean(y)
    y = (y-mean)/(width)
    return X,y

# %%
for i in pd.read_csv('E:/catalogues/final_quasar_catalogue.csv', sep=',', header=0,squeeze=True).columns:
    print(i)
