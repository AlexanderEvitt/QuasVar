# %%
import numpy as np
from pickle import dump, load
from numpy import array
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout, Bidirectional, Conv1D, MaxPooling1D, Flatten
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import SGD, Adam
from tensorflow.keras.utils import plot_model, model_to_dot
from os import listdir
import lightkurve as lk
import pickle
import pandas as pd
from collections import Counter
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

def build_rnn(X,lstm_layers,cells,output_size):
    model = Sequential()
    
    #model.add(Dense(units=cells,input_shape=(X.shape[1], X.shape[2])))
    for i in range(lstm_layers - 1):
        model.add(Bidirectional(LSTM(cells,activation='sigmoid',return_sequences=True)))
        model.add(Dropout(0.2))
        
    model.add(Bidirectional(LSTM(cells,activation='sigmoid')))
    model.add(Dropout(0.2))
    
    model.add(Dense(output_size, activation='softmax'))

    opt = Adam(learning_rate=0.00001)
    model.compile(loss = "categorical_crossentropy", metrics=['categorical_accuracy'], optimizer = opt)
    return model

def build_cnn(X):
    model = Sequential()
    
    model.add(Conv1D(filters=380, kernel_size=7, activation='relu', input_shape=(760, 1)))
    model.add(MaxPooling1D(pool_size=2))
    
    model.add(Conv1D(filters=190, kernel_size=7, activation='relu', input_shape=(760, 1)))
    model.add(MaxPooling1D(pool_size=2))
    
    model.add(Conv1D(filters=95, kernel_size=7, activation='relu', input_shape=(760, 1)))
    model.add(MaxPooling1D(pool_size=2))
    
    model.add(Conv1D(filters=47, kernel_size=7, activation='relu', input_shape=(760, 1)))
    model.add(MaxPooling1D(pool_size=2))
    
    model.add(Conv1D(filters=24, kernel_size=7, activation='relu', input_shape=(760, 1)))
    model.add(MaxPooling1D(pool_size=2))
    
    model.add(Flatten())
    model.add(Dense(20,activation='relu'))
    model.add(Dense(10,activation='relu'))
    model.add(Dense(6,activation='softmax'))

    opt = Adam(learning_rate=0.0000001)
    model.compile(loss = "categorical_crossentropy", metrics=['categorical_accuracy'], optimizer = opt)
    return model

x = np.load('x_magless.npy')
y = np.load('y_magless.npy')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-c9048feae4df> in <module>
#       2 from pickle import dump, load
#       3 from numpy import array
# ----> 4 from tensorflow.keras.utils import to_categorical
#       5 from tensorflow.keras.models import Sequential
#       6 from tensorflow.keras.layers import Dense, LSTM, Dropout, Bidirectional, Conv1D, MaxPooling1D, Flatten
#
# ~\Anaconda3\lib\site-packages\tensorflow\__init__.py in <module>
#      39 import sys as _sys
#      40
# ---> 41 from tensorflow.python.tools import module_util as _module_util
#      42 from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
#      43
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\__init__.py in <module>
#      51
#      52 # Protocol buffers
# ---> 53 from tensorflow.core.framework.graph_pb2 import *
#      54 from tensorflow.core.framework.node_def_pb2 import *
#      55 from tensorflow.core.framework.summary_pb2 import *
#
# ~\Anaconda3\lib\site-packages\tensorflow\core\framework\graph_pb2.py in <module>
#       5 import sys
#       6 _b=sys.version_info[0]<3 and (lambda x:x) or (lambda x:x.encode('latin1'))
# ----> 7 from google.protobuf import descriptor as _descriptor
#       8 from google.protobuf import message as _message
#       9 from google.protobuf import reflection as _reflection
#
# ImportError: cannot import name 'descriptor' from 'google.protobuf' (unknown location)

# %%
model = build_rnn(x,lstm_layers=2,cells=50,output_size=6)

history = model.fit(x, y, epochs=10, verbose=1,batch_size=100, validation_split=0.2, shuffle=True)
model.save(str('bot3.h5'))

# %%
model = build_cnn(x)
model.summary()

history = model.fit(x, y, epochs=400, verbose=1,batch_size=100, validation_split=0.2, shuffle=True)
model.save(str('bot3.h5'))
# Out:
# Model: "sequential_19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_69 (Conv1D)           (None, 754, 380)          3040
# _________________________________________________________________
# max_pooling1d_66 (MaxPooling (None, 377, 380)          0
# _________________________________________________________________
# conv1d_70 (Conv1D)           (None, 371, 190)          505590
# _________________________________________________________________
# max_pooling1d_67 (MaxPooling (None, 185, 190)          0
# _________________________________________________________________
# conv1d_71 (Conv1D)           (None, 179, 95)           126445
# _________________________________________________________________
# max_pooling1d_68 (MaxPooling (None, 89, 95)            0
# _________________________________________________________________
# conv1d_72 (Conv1D)           (None, 83, 47)            31302
# _________________________________________________________________
# max_pooling1d_69 (MaxPooling (None, 41, 47)            0
# _________________________________________________________________
# conv1d_73 (Conv1D)           (None, 35, 24)            7920
# _________________________________________________________________
# max_pooling1d_70 (MaxPooling (None, 17, 24)            0
# _________________________________________________________________
# flatten_18 (Flatten)         (None, 408)               0
# _________________________________________________________________
# dense_48 (Dense)             (None, 20)                8180
# _________________________________________________________________
# dense_49 (Dense)             (None, 10)                210
# _________________________________________________________________
# dense_50 (Dense)             (None, 6)                 66
# =================================================================
# Total params: 682,753
# Trainable params: 682,753
# Non-trainable params: 0
# _________________________________________________________________
# Train on 15164 samples, validate on 3791 samples
# Epoch 1/400
# 15164/15164 [==============================] - 9s 593us/sample - loss: 1.8009 - categorical_accuracy: 0.1120 - val_loss: 1.7971 - val_categorical_accuracy: 0.1269
# Epoch 2/400
# 15164/15164 [==============================] - 7s 450us/sample - loss: 1.8001 - categorical_accuracy: 0.1120 - val_loss: 1.7967 - val_categorical_accuracy: 0.1277
# Epoch 3/400
# 15164/15164 [==============================] - 7s 458us/sample - loss: 1.7995 - categorical_accuracy: 0.1123 - val_loss: 1.7964 - val_categorical_accuracy: 0.1269
# Epoch 4/400
# 15164/15164 [==============================] - 7s 492us/sample - loss: 1.7988 - categorical_accuracy: 0.1129 - val_loss: 1.7961 - val_categorical_accuracy: 0.1279
# Epoch 5/400
# 15164/15164 [==============================] - 7s 458us/sample - loss: 1.7983 - categorical_accuracy: 0.1134 - val_loss: 1.7958 - val_categorical_accuracy: 0.1274
# Epoch 6/400
# 15164/15164 [==============================] - 7s 467us/sample - loss: 1.7979 - categorical_accuracy: 0.1129 - val_loss: 1.7956 - val_categorical_accuracy: 0.1279
# Epoch 7/400
# 15164/15164 [==============================] - 7s 462us/sample - loss: 1.7975 - categorical_accuracy: 0.1130 - val_loss: 1.7954 - val_categorical_accuracy: 0.1298
# Epoch 8/400
# 15164/15164 [==============================] - 7s 463us/sample - loss: 1.7971 - categorical_accuracy: 0.1128 - val_loss: 1.7952 - val_categorical_accuracy: 0.1290
# Epoch 9/400
# 15164/15164 [==============================] - 7s 467us/sample - loss: 1.7937 - categorical_accuracy: 0.1389 - val_loss: 1.7936 - val_categorical_accuracy: 0.1395
# Epoch 27/400
# 15164/15164 [==============================] - 7s 466us/sample - loss: 1.7936 - categorical_accuracy: 0.1417 - val_loss: 1.7935 - val_categorical_accuracy: 0.1427
# Epoch 28/400
# 15164/15164 [==============================] - 7s 467us/sample - loss: 1.7935 - categorical_accuracy: 0.1427 - val_loss: 1.7935 - val_categorical_accuracy: 0.1451
# Epoch 29/400
# 15164/15164 [==============================] - 7s 468us/sample - loss: 1.7935 - categorical_accuracy: 0.1449 - val_loss: 1.7935 - val_categorical_accuracy: 0.1446
# Epoch 30/400
# 15164/15164 [==============================] - 7s 467us/sample - loss: 1.7934 - categorical_accuracy: 0.1462 - val_loss: 1.7934 - val_categorical_accuracy: 0.1461
# Epoch 31/400
# 15164/15164 [==============================] - 7s 478us/sample - loss: 1.7933 - categorical_accuracy: 0.1500 - val_loss: 1.7934 - val_categorical_accuracy: 0.1475
# Epoch 32/400
# 15164/15164 [==============================] - 7s 467us/sample - loss: 1.7932 - categorical_accuracy: 0.1515 - val_loss: 1.7934 - val_categorical_accuracy: 0.1461
# Epoch 33/400
# 15164/15164 [==============================] - 7s 467us/sample - loss: 1.7931 - categorical_accuracy: 0.1521 - val_loss: 1.7933 - val_categorical_accuracy: 0.1464
# Epoch 34/400
# 15164/15164 [==============================] - 7s 468us/sample - loss: 1.7931 - categorical_accuracy: 0.1531 - val_loss: 1.7933 - val_categorical_accuracy: 0.1464
# Epoch 35/400
# 15164/15164 [==============================] - 7s 468us/sample - loss: 1.7930 - categorical_accuracy: 0.1546 - val_loss: 1.7933 - val_categorical_accuracy: 0.1464
# Epoch 36/400
# 15164/15164 [==============================] - 7s 466us/sample - loss: 1.7930 - categorical_accuracy: 0.1569 - val_loss: 1.7933 - val_categorical_accuracy: 0.1485
# Epoch 37/400
# 15164/15164 [==============================] - 7s 468us/sample - loss: 1.7929 - categorical_accuracy: 0.1585 - val_loss: 1.7932 - val_categorical_accuracy: 0.1504
# Epoch 38/400
# 15164/15164 [==============================] - 7s 467us/sample - loss: 1.7928 - categorical_accuracy: 0.1609 - val_loss: 1.7932 - val_categorical_accuracy: 0.1509
# Epoch 39/400
# 15164/15164 [==============================] - 7s 468us/sample - loss: 1.7928 - categorical_accuracy: 0.1623 - val_loss: 1.7932 - val_categorical_accuracy: 0.1525
# Epoch 40/400
# 15164/15164 [==============================] - 7s 467us/sample - loss: 1.7927 - categorical_accuracy: 0.1644 - val_loss: 1.7932 - val_categorical_accuracy: 0.1530
# Epoch 41/400
# 15164/15164 [==============================] - 7s 467us/sample - loss: 1.7927 - categorical_accuracy: 0.1665 - val_loss: 1.7931 - val_categorical_accuracy: 0.1506
# Epoch 42/400
# 15164/15164 [==============================] - 7s 470us/sample - loss: 1.7926 - categorical_accuracy: 0.1676 - val_loss: 1.7931 - val_categorical_accuracy: 0.1525
# Epoch 43/400
# 15164/15164 [==============================] - 7s 467us/sample - loss: 1.7926 - categorical_accuracy: 0.1697 - val_loss: 1.7931 - val_categorical_accuracy: 0.1525
# Epoch 44/400
# 15164/15164 [==============================] - 7s 468us/sample - loss: 1.7925 - categorical_accuracy: 0.1721 - val_loss: 1.7931 - val_categorical_accuracy: 0.1530
# Epoch 45/400
# 15164/15164 [==============================] - 7s 467us/sample - loss: 1.7925 - categorical_accuracy: 0.1737 - val_loss: 1.7930 - val_categorical_accuracy: 0.1551
# Epoch 46/400
# 15164/15164 [==============================] - 7s 468us/sample - loss: 1.7924 - categorical_accuracy: 0.1753 - val_loss: 1.7930 - val_categorical_accuracy: 0.1564
# Epoch 47/400
# 15164/15164 [==============================] - 7s 467us/sample - loss: 1.7923 - categorical_accuracy: 0.1763 - val_loss: 1.7930 - val_categorical_accuracy: 0.1596
# Epoch 48/400
# 15164/15164 [==============================] - 7s 468us/sample - loss: 1.7923 - categorical_accuracy: 0.1770 - val_loss: 1.7930 - val_categorical_accuracy: 0.1604
# Epoch 49/400
# 15164/15164 [==============================] - 7s 467us/sample - loss: 1.7922 - categorical_accuracy: 0.1796 - val_loss: 1.7929 - val_categorical_accuracy: 0.1614
# Epoch 50/400
# 15164/15164 [==============================] - 7s 468us/sample - loss: 1.7922 - categorical_accuracy: 0.1810 - val_loss: 1.7929 - val_categorical_accuracy: 0.1628
# Epoch 51/400
# 15164/15164 [==============================] - 7s 466us/sample - loss: 1.7921 - categorical_accuracy: 0.1824 - val_loss: 1.7929 - val_categorical_accuracy: 0.1641
# Epoch 52/400
# 15164/15164 [==============================] - 7s 467us/sample - loss: 1.7921 - categorical_accuracy: 0.1837 - val_loss: 1.7929 - val_categorical_accuracy: 0.1654
# Epoch 53/400
# 15164/15164 [==============================] - 7s 468us/sample - loss: 1.7920 - categorical_accuracy: 0.1844 - val_loss: 1.7928 - val_categorical_accuracy: 0.1672
# Epoch 54/400
# 15164/15164 [==============================] - 7s 466us/sample - loss: 1.7920 - categorical_accuracy: 0.1843 - val_loss: 1.7928 - val_categorical_accuracy: 0.1675
# Epoch 55/400
# 15164/15164 [==============================] - 7s 469us/sample - loss: 1.7919 - categorical_accuracy: 0.1849 - val_loss: 1.7928 - val_categorical_accuracy: 0.1680
# Epoch 56/400
# 15164/15164 [==============================] - 7s 467us/sample - loss: 1.7919 - categorical_accuracy: 0.1868 - val_loss: 1.7928 - val_categorical_accuracy: 0.1696
# Epoch 57/400
# 15164/15164 [==============================] - 7s 469us/sample - loss: 1.7918 - categorical_accuracy: 0.1876 - val_loss: 1.7927 - val_categorical_accuracy: 0.1699
# Epoch 58/400
# 15164/15164 [==============================] - 7s 469us/sample - loss: 1.7918 - categorical_accuracy: 0.1887 - val_loss: 1.7927 - val_categorical_accuracy: 0.1707
# Epoch 59/400
# 15164/15164 [==============================] - 7s 467us/sample - loss: 1.7917 - categorical_accuracy: 0.1897 - val_loss: 1.7927 - val_categorical_accuracy: 0.1715
# Epoch 60/400
# Epoch 111/400
# 15164/15164 [==============================] - 7s 471us/sample - loss: 1.7878 - categorical_accuracy: 0.2105 - val_loss: 1.7903 - val_categorical_accuracy: 0.1865
# Epoch 112/400
# 15164/15164 [==============================] - 7s 466us/sample - loss: 1.7877 - categorical_accuracy: 0.2110 - val_loss: 1.7902 - val_categorical_accuracy: 0.1873
# Epoch 113/400
# 15164/15164 [==============================] - 7s 466us/sample - loss: 1.7876 - categorical_accuracy: 0.2110 - val_loss: 1.7902 - val_categorical_accuracy: 0.1873
# Epoch 114/400
# 15164/15164 [==============================] - 7s 491us/sample - loss: 1.7876 - categorical_accuracy: 0.2112 - val_loss: 1.7901 - val_categorical_accuracy: 0.1881
# Epoch 115/400
# 15164/15164 [==============================] - 7s 481us/sample - loss: 1.7875 - categorical_accuracy: 0.2116 - val_loss: 1.7901 - val_categorical_accuracy: 0.1881
# Epoch 116/400
# 15164/15164 [==============================] - 7s 467us/sample - loss: 1.7874 - categorical_accuracy: 0.2116 - val_loss: 1.7900 - val_categorical_accuracy: 0.1899
# Epoch 117/400
# 15164/15164 [==============================] - 7s 465us/sample - loss: 1.7873 - categorical_accuracy: 0.2118 - val_loss: 1.7900 - val_categorical_accuracy: 0.1889
# Epoch 118/400
# 15164/15164 [==============================] - 7s 492us/sample - loss: 1.7872 - categorical_accuracy: 0.2121 - val_loss: 1.7899 - val_categorical_accuracy: 0.1886
# Epoch 119/400
# 15164/15164 [==============================] - 7s 467us/sample - loss: 1.7871 - categorical_accuracy: 0.2125 - val_loss: 1.7899 - val_categorical_accuracy: 0.1878
# Epoch 120/400
# 15164/15164 [==============================] - 7s 477us/sample - loss: 1.7870 - categorical_accuracy: 0.2128 - val_loss: 1.7898 - val_categorical_accuracy: 0.1873
# Epoch 121/400
# 15164/15164 [==============================] - 7s 493us/sample - loss: 1.7870 - categorical_accuracy: 0.2131 - val_loss: 1.7898 - val_categorical_accuracy: 0.1873
# Epoch 122/400
# 15164/15164 [==============================] - 7s 487us/sample - loss: 1.7869 - categorical_accuracy: 0.2131 - val_loss: 1.7897 - val_categorical_accuracy: 0.1865
# Epoch 123/400
# 15164/15164 [==============================] - 7s 464us/sample - loss: 1.7868 - categorical_accuracy: 0.2126 - val_loss: 1.7896 - val_categorical_accuracy: 0.1875
# Epoch 124/400
# 15164/15164 [==============================] - 8s 506us/sample - loss: 1.7867 - categorical_accuracy: 0.2131 - val_loss: 1.7896 - val_categorical_accuracy: 0.1889
# Epoch 125/400
# 15164/15164 [==============================] - 7s 486us/sample - loss: 1.7866 - categorical_accuracy: 0.2133 - val_loss: 1.7895 - val_categorical_accuracy: 0.1886
# Epoch 126/400
# 15164/15164 [==============================] - 8s 504us/sample - loss: 1.7865 - categorical_accuracy: 0.2134 - val_loss: 1.7895 - val_categorical_accuracy: 0.1889
# Epoch 127/400
# 15164/15164 [==============================] - 7s 458us/sample - loss: 1.7864 - categorical_accuracy: 0.2135 - val_loss: 1.7894 - val_categorical_accuracy: 0.1889
# 15164/15164 [==============================] - 7s 473us/sample - loss: 1.7683 - categorical_accuracy: 0.2185 - val_loss: 1.7807 - val_categorical_accuracy: 0.1928
# Epoch 247/400
# 15164/15164 [==============================] - 7s 469us/sample - loss: 1.7681 - categorical_accuracy: 0.2186 - val_loss: 1.7807 - val_categorical_accuracy: 0.1928
# Epoch 248/400
# 15164/15164 [==============================] - 7s 477us/sample - loss: 1.7679 - categorical_accuracy: 0.2186 - val_loss: 1.7806 - val_categorical_accuracy: 0.1928
# Epoch 249/400
# 15164/15164 [==============================] - 7s 473us/sample - loss: 1.7677 - categorical_accuracy: 0.2188 - val_loss: 1.7805 - val_categorical_accuracy: 0.1928
# Epoch 250/400
# 15164/15164 [==============================] - 7s 475us/sample - loss: 1.7675 - categorical_accuracy: 0.2189 - val_loss: 1.7804 - val_categorical_accuracy: 0.1928
# Epoch 251/400
# 15164/15164 [==============================] - 7s 473us/sample - loss: 1.7674 - categorical_accuracy: 0.2188 - val_loss: 1.7803 - val_categorical_accuracy: 0.1928
# Epoch 252/400
# 15164/15164 [==============================] - 7s 465us/sample - loss: 1.7672 - categorical_accuracy: 0.2187 - val_loss: 1.7802 - val_categorical_accuracy: 0.1934
# Epoch 253/400
# 15164/15164 [==============================] - 8s 527us/sample - loss: 1.7670 - categorical_accuracy: 0.2186 - val_loss: 1.7802 - val_categorical_accuracy: 0.1934
# Epoch 254/400
# 15164/15164 [==============================] - 7s 469us/sample - loss: 1.7668 - categorical_accuracy: 0.2187 - val_loss: 1.7801 - val_categorical_accuracy: 0.1936
# Epoch 255/400
# 15164/15164 [==============================] - 7s 465us/sample - loss: 1.7666 - categorical_accuracy: 0.2189 - val_loss: 1.7800 - val_categorical_accuracy: 0.1934
# Epoch 256/400
# 15164/15164 [==============================] - 7s 481us/sample - loss: 1.7665 - categorical_accuracy: 0.2189 - val_loss: 1.7799 - val_categorical_accuracy: 0.1934
# Epoch 257/400
# 15164/15164 [==============================] - 8s 535us/sample - loss: 1.7663 - categorical_accuracy: 0.2189 - val_loss: 1.7798 - val_categorical_accuracy: 0.1934
# Epoch 258/400
# 15164/15164 [==============================] - 8s 496us/sample - loss: 1.7661 - categorical_accuracy: 0.2191 - val_loss: 1.7798 - val_categorical_accuracy: 0.1936
# Epoch 259/400
# ...
# Epoch 311/400
# 15164/15164 [==============================] - 8s 501us/sample - loss: 1.7597 - categorical_accuracy: 0.2206 - val_loss: 1.7771 - val_categorical_accuracy: 0.1931
# Epoch 312/400
# 15164/15164 [==============================] - 7s 466us/sample - loss: 1.7596 - categorical_accuracy: 0.2205 - val_loss: 1.7770 - val_categorical_accuracy: 0.1931
# Epoch 313/400
# 15164/15164 [==============================] - 7s 455us/sample - loss: 1.7595 - categorical_accuracy: 0.2204 - val_loss: 1.7770 - val_categorical_accuracy: 0.1934
# Epoch 314/400
# 15164/15164 [==============================] - 7s 459us/sample - loss: 1.7595 - categorical_accuracy: 0.2204 - val_loss: 1.7770 - val_categorical_accuracy: 0.1934
# Epoch 315/400
# 15164/15164 [==============================] - 7s 479us/sample - loss: 1.7594 - categorical_accuracy: 0.2205 - val_loss: 1.7770 - val_categorical_accuracy: 0.1934
# Epoch 316/400
# 15164/15164 [==============================] - 7s 454us/sample - loss: 1.7593 - categorical_accuracy: 0.2204 - val_loss: 1.7769 - val_categorical_accuracy: 0.1934
# Epoch 317/400
# 15164/15164 [==============================] - 7s 469us/sample - loss: 1.7593 - categorical_accuracy: 0.2204 - val_loss: 1.7769 - val_categorical_accuracy: 0.1934
# Epoch 318/400
# 15164/15164 [==============================] - 7s 459us/sample - loss: 1.7592 - categorical_accuracy: 0.2204 - val_loss: 1.7769 - val_categorical_accuracy: 0.1936
# Epoch 319/400
# 15164/15164 [==============================] - 7s 454us/sample - loss: 1.7591 - categorical_accuracy: 0.2202 - val_loss: 1.7769 - val_categorical_accuracy: 0.1936
# Epoch 320/400
# 15164/15164 [==============================] - 7s 483us/sample - loss: 1.7591 - categorical_accuracy: 0.2202 - val_loss: 1.7768 - val_categorical_accuracy: 0.1936
# Epoch 321/400
# 15164/15164 [==============================] - 7s 469us/sample - loss: 1.7590 - categorical_accuracy: 0.2202 - val_loss: 1.7768 - val_categorical_accuracy: 0.1936
# Epoch 322/400
# 15164/15164 [==============================] - 7s 454us/sample - loss: 1.7590 - categorical_accuracy: 0.2204 - val_loss: 1.7768 - val_categorical_accuracy: 0.1936
# Epoch 323/400
# 15164/15164 [==============================] - 8s 501us/sample - loss: 1.7589 - categorical_accuracy: 0.2201 - val_loss: 1.7768 - val_categorical_accuracy: 0.1939
# Epoch 324/400
# 15164/15164 [==============================] - 7s 457us/sample - loss: 1.7588 - categorical_accuracy: 0.2200 - val_loss: 1.7768 - val_categorical_accuracy: 0.1939
# Epoch 325/400
# 15164/15164 [==============================] - 7s 454us/sample - loss: 1.7588 - categorical_accuracy: 0.2200 - val_loss: 1.7767 - val_categorical_accuracy: 0.1939
# Epoch 326/400
# 15164/15164 [==============================] - 7s 454us/sample - loss: 1.7587 - categorical_accuracy: 0.2199 - val_loss: 1.7767 - val_categorical_accuracy: 0.1939
# Epoch 327/400
# 15164/15164 [==============================] - 7s 454us/sample - loss: 1.7587 - categorical_accuracy: 0.2198 - val_loss: 1.7767 - val_categorical_accuracy: 0.1941
# Epoch 328/400
# 15164/15164 [==============================] - 7s 476us/sample - loss: 1.7586 - categorical_accuracy: 0.2195 - val_loss: 1.7767 - val_categorical_accuracy: 0.1944
# Epoch 329/400
# 15164/15164 [==============================] - 8s 510us/sample - loss: 1.7586 - categorical_accuracy: 0.2196 - val_loss: 1.7767 - val_categorical_accuracy: 0.1944
# Epoch 330/400
# 15164/15164 [==============================] - 7s 460us/sample - loss: 1.7585 - categorical_accuracy: 0.2195 - val_loss: 1.7766 - val_categorical_accuracy: 0.1944
# Epoch 331/400
# 15164/15164 [==============================] - 7s 456us/sample - loss: 1.7585 - categorical_accuracy: 0.2197 - val_loss: 1.7766 - val_categorical_accuracy: 0.1944
# Epoch 332/400
# 15164/15164 [==============================] - 7s 455us/sample - loss: 1.7577 - categorical_accuracy: 0.2202 - val_loss: 1.7763 - val_categorical_accuracy: 0.1952
# Epoch 350/400
# 15164/15164 [==============================] - 7s 455us/sample - loss: 1.7576 - categorical_accuracy: 0.2205 - val_loss: 1.7763 - val_categorical_accuracy: 0.1949
# Epoch 351/400
# 15164/15164 [==============================] - 7s 469us/sample - loss: 1.7576 - categorical_accuracy: 0.2203 - val_loss: 1.7763 - val_categorical_accuracy: 0.1949
# Epoch 352/400
# 15164/15164 [==============================] - 7s 459us/sample - loss: 1.7576 - categorical_accuracy: 0.2203 - val_loss: 1.7763 - val_categorical_accuracy: 0.1949
# Epoch 353/400
# 15164/15164 [==============================] - 7s 454us/sample - loss: 1.7575 - categorical_accuracy: 0.2206 - val_loss: 1.7763 - val_categorical_accuracy: 0.1949
# Epoch 354/400
# 15164/15164 [==============================] - 7s 457us/sample - loss: 1.7575 - categorical_accuracy: 0.2205 - val_loss: 1.7762 - val_categorical_accuracy: 0.1949
# Epoch 355/400
# 15164/15164 [==============================] - 7s 457us/sample - loss: 1.7575 - categorical_accuracy: 0.2205 - val_loss: 1.7762 - val_categorical_accuracy: 0.1949
# Epoch 356/400
# 15164/15164 [==============================] - 7s 455us/sample - loss: 1.7574 - categorical_accuracy: 0.2205 - val_loss: 1.7762 - val_categorical_accuracy: 0.1952
# Epoch 357/400
# 15164/15164 [==============================] - 7s 460us/sample - loss: 1.7574 - categorical_accuracy: 0.2207 - val_loss: 1.7762 - val_categorical_accuracy: 0.1960
# Epoch 358/400
# 15164/15164 [==============================] - 7s 454us/sample - loss: 1.7573 - categorical_accuracy: 0.2206 - val_loss: 1.7762 - val_categorical_accuracy: 0.1963
# Epoch 359/400
# 15164/15164 [==============================] - 7s 472us/sample - loss: 1.7573 - categorical_accuracy: 0.2204 - val_loss: 1.7762 - val_categorical_accuracy: 0.1960
# Epoch 360/400
# 15164/15164 [==============================] - 7s 463us/sample - loss: 1.7573 - categorical_accuracy: 0.2205 - val_loss: 1.7762 - val_categorical_accuracy: 0.1957
# Epoch 361/400
# 15164/15164 [==============================] - 7s 455us/sample - loss: 1.7572 - categorical_accuracy: 0.2207 - val_loss: 1.7761 - val_categorical_accuracy: 0.1957
# Epoch 362/400
# 15164/15164 [==============================] - 7s 455us/sample - loss: 1.7572 - categorical_accuracy: 0.2207 - val_loss: 1.7761 - val_categorical_accuracy: 0.1957
# Epoch 363/400
# 15164/15164 [==============================] - 7s 456us/sample - loss: 1.7572 - categorical_accuracy: 0.2207 - val_loss: 1.7761 - val_categorical_accuracy: 0.1965
# Epoch 364/400
# 15164/15164 [==============================] - 7s 456us/sample - loss: 1.7571 - categorical_accuracy: 0.2207 - val_loss: 1.7761 - val_categorical_accuracy: 0.1968
# Epoch 365/400
# 15164/15164 [==============================] - 7s 456us/sample - loss: 1.7571 - categorical_accuracy: 0.2208 - val_loss: 1.7761 - val_categorical_accuracy: 0.1970
# Epoch 366/400
# Epoch 383/400
# 15164/15164 [==============================] - 7s 457us/sample - loss: 1.7566 - categorical_accuracy: 0.2217 - val_loss: 1.7759 - val_categorical_accuracy: 0.1981
# Epoch 384/400
# 15164/15164 [==============================] - 7s 456us/sample - loss: 1.7566 - categorical_accuracy: 0.2217 - val_loss: 1.7758 - val_categorical_accuracy: 0.1981
# Epoch 385/400
# 15164/15164 [==============================] - 7s 456us/sample - loss: 1.7565 - categorical_accuracy: 0.2217 - val_loss: 1.7758 - val_categorical_accuracy: 0.1984
# Epoch 386/400
# 15164/15164 [==============================] - 7s 456us/sample - loss: 1.7565 - categorical_accuracy: 0.2216 - val_loss: 1.7758 - val_categorical_accuracy: 0.1984
# Epoch 387/400
# 15164/15164 [==============================] - 7s 456us/sample - loss: 1.7565 - categorical_accuracy: 0.2217 - val_loss: 1.7758 - val_categorical_accuracy: 0.1984
# Epoch 388/400
# 15164/15164 [==============================] - 7s 456us/sample - loss: 1.7565 - categorical_accuracy: 0.2216 - val_loss: 1.7758 - val_categorical_accuracy: 0.1986
# Epoch 389/400
# 15164/15164 [==============================] - 7s 456us/sample - loss: 1.7564 - categorical_accuracy: 0.2216 - val_loss: 1.7758 - val_categorical_accuracy: 0.1986
# Epoch 390/400
# 15164/15164 [==============================] - 7s 456us/sample - loss: 1.7564 - categorical_accuracy: 0.2214 - val_loss: 1.7758 - val_categorical_accuracy: 0.1984
# Epoch 391/400
# 15164/15164 [==============================] - 7s 456us/sample - loss: 1.7564 - categorical_accuracy: 0.2214 - val_loss: 1.7758 - val_categorical_accuracy: 0.1984
# Epoch 392/400
# 15164/15164 [==============================] - 7s 456us/sample - loss: 1.7564 - categorical_accuracy: 0.2214 - val_loss: 1.7758 - val_categorical_accuracy: 0.1981
# Epoch 393/400
# 15164/15164 [==============================] - 7s 456us/sample - loss: 1.7563 - categorical_accuracy: 0.2216 - val_loss: 1.7758 - val_categorical_accuracy: 0.1976
# Epoch 394/400
# 15164/15164 [==============================] - 7s 456us/sample - loss: 1.7563 - categorical_accuracy: 0.2218 - val_loss: 1.7757 - val_categorical_accuracy: 0.1984
# Epoch 395/400
# 15164/15164 [==============================] - 7s 457us/sample - loss: 1.7563 - categorical_accuracy: 0.2218 - val_loss: 1.7757 - val_categorical_accuracy: 0.1984
# Epoch 396/400
# 15164/15164 [==============================] - 7s 456us/sample - loss: 1.7563 - categorical_accuracy: 0.2218 - val_loss: 1.7757 - val_categorical_accuracy: 0.1984
# Epoch 397/400
# 15164/15164 [==============================] - 7s 457us/sample - loss: 1.7562 - categorical_accuracy: 0.2219 - val_loss: 1.7757 - val_categorical_accuracy: 0.1986
# Epoch 398/400
# 15164/15164 [==============================] - 7s 457us/sample - loss: 1.7562 - categorical_accuracy: 0.2216 - val_loss: 1.7757 - val_categorical_accuracy: 0.1986
# Epoch 399/400
# 15164/15164 [==============================] - 7s 456us/sample - loss: 1.7562 - categorical_accuracy: 0.2216 - val_loss: 1.7757 - val_categorical_accuracy: 0.1984
# Epoch 400/400
# 15164/15164 [==============================] - 7s 456us/sample - loss: 1.7562 - categorical_accuracy: 0.2215 - val_loss: 1.7757 - val_categorical_accuracy: 0.1989

# %%
#plt.plot(history.history['categorical_accuracy'])
#plt.plot(history.history['val_categorical_accuracy'])
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Accuracy')
plt.ylabel('accuarcy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
#plt.ylim(bottom=0.1,top=0.3)
plt.show()

# %%
def unencode(matrix):
    new_matrix = np.zeros(matrix.shape[0])
    for i in range(matrix.shape[0]):
        val = np.argmax(matrix[i])
        new_matrix[i] = classes[val]
    return new_matrix

y_pred = model.predict(x, verbose=0)

classes = [0,1,2,3,4,5]
cm = confusion_matrix(unencode(y),unencode(y_pred),labels=classes)
plt.imshow(np.log(cm),cmap='Blues')
plt.xlabel('Predicted y-values')
plt.ylabel('Actual y-values')
plt.colorbar()
plt.show()

print(cm)
# Out:
# C:\Users\811261\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:12: RuntimeWarning: divide by zero encountered in log
#   if sys.path[0] == '':
# [[  38    8  111   98 1874    2]
#  [  35    7   97   56 1851    4]
#  [  62    7  172  131 2799    0]
#  [  79   14  202  180 3869    3]
#  [  59    8  194  136 3712    5]
#  [  58    9  150  112 2809    4]]

# %%
i = 76#86
b = 20
good = []
bad = []
values = pd.read_csv('E:/catalogues/final_quasar_catalogue.csv', sep=',', usecols=[i],header=0,squeeze=True).to_numpy()
print(pd.read_csv('E:/catalogues/final_quasar_catalogue.csv', sep=',', header=0,squeeze=True).columns[i])
pred = unencode(y_pred)
act = unencode(y)
for n in range(len(x)):
    value = values[n]
    if pred[n] == act[n]:
        good.append(value)
    else:
        bad.append(value)
        
print('bad:',np.mean(bad),'good:',np.mean(good))
plt.hist(good,bins=b,color='g',alpha=0.5)
plt.hist(bad,bins=b,color='r',alpha=0.5)
plt.show()

'''
REWE_CIII
BI_CIV
MI
VAR_CHI2 - bad results are way more variable

'''
# Out:
# VAR_CHI2
# bad: 19.824316126163346 good: 15.657505683565045
# '\nREWE_CIII\nBI_CIV\nMI\nVAR_CHI2 - bad results are way more variable\n\n'

# %%
from scipy.stats import ttest_1samp

good = []
bad = []
pred = unencode(y_pred)
act = unencode(y)
for n in range(len(x)):
    value = np.sum(np.abs(x[n,:,0]-1))
    if pred[n] == act[n]:
        good.append(value)
    else:
        bad.append(value)
        
print('bad:',np.mean(bad),'good:',np.mean(good))
plt.hist(good,bins=100,color='g',alpha=0.5)
plt.hist(bad,bins=100,color='r',alpha=0.5)
plt.show()
# Out:
# bad: 873.7732874071093 good: 872.9535558624192

# %%
for cut in np.linspace(-28,-22,60):
    good_cut = [good[i] for i in range(len(good)) if good[i] < cut+0.2 and good[i]>cut]
    bad_cut = [bad[i] for i in range(len(bad)) if bad[i] < cut+0.2 and bad[i]>cut]
    plt.scatter(cut,len(good_cut)/(len(good_cut)+len(bad_cut)),c='b')

# %%
good_cut = [good[i] for i in range(len(good)) if good[i] > 0]
bad_cut = [bad[i] for i in range(len(bad)) if bad[i] > 0]
print(len(good_cut)/(len(good_cut)+len(bad_cut)))
# Out:
# 0.2936361047835991

# %%
values
# Out:
# array([0, 0, 0, ..., 0, 4, 6], dtype=int64)

# %%
import os
places = []
files = os.listdir('E:/sector_lightcurves/')
predictions = unencode(y_pred)
actual = unencode(y)
for n in range(len(predictions)):
    if predictions[n] == 4:
        if actual[n] == 4:
            places.append(files[n])

# %%
import lightkurve as lk
import pickle
import matplotlib.pyplot as plt

lc_dir = 'E:/sector_lightcurves/'

def load(file='1lc.pickle',width=18,height=3,dpi=1000,alpha=0.75,bin=True,bins=2000,sigma=20,save=False):
    plt.figure(figsize=(width, height), dpi=dpi)
    with open(file,'rb') as rfile:
        lc = pickle.load(rfile)
    lc.quality = np.zeros(len(lc.flux),dtype='int')
    if bin == True:
        lc = lc.remove_nans().remove_outliers(sigma=sigma).bin(bins=bins)
    elif bin == False:
        lc = lc.remove_nans().remove_outliers(sigma=sigma)
    plt.plot(lc.time,lc.flux,color='blue',alpha=alpha,label='TIC ' + str(lc.targetid))
    #plt.xlim(left=1340,right=1380)
    plt.xlabel("Time (BTJD Days)")
    plt.ylabel("Flux (e/s)")
    plt.title("Flux as a function of time for " + 'TIC ' + str(lc.targetid))
    if save == True:
        plt.savefig(str(file) + ".png")

# %%
def generate_data(data_path, data_amount, bins=1000):
    if data_amount == 'auto':
        data_amount = len(listdir(data_path))
    print("There are {0} lightcurves present in the data_path".format(data_amount))
    list_files = listdir(data_path)[0:data_amount]
    
    # generate lightcurve data
    X = np.zeros((0,bins,2))
    rows = []
    for file in list_files:
        with open(data_path + '/' + file, 'rb') as rfile:
            lc = pickle.load(rfile)
        if len(lc.flux)< bins:
            continue
        lc.quality = np.zeros(len(lc.flux),dtype='int')
        lc = lc.remove_outliers(sigma=20).remove_nans()
        flux = np.reshape(np.array([lc.time[:bins]]),(bins,1))
        flux_norm = (flux)/(np.max(flux)-np.min(flux))
        time = np.reshape(np.array([lc.flux[:bins]]),(bins,1))
        time_norm = (time - np.mean(time))/(np.max(time)-np.min(time))
        X_curve = np.array([np.concatenate((flux,time),axis=1)])

        X = np.concatenate((X,X_curve),axis=0)
        row = int(file.split('-')[0])
        rows.append(row)
    print('Generating lightcurve data complete')
    
    what_rows = []
    [what_rows.append(x) for x in rows if x not in what_rows]
    count_rows = Counter(rows)
    print('Objects identified')
    y = []
    ya = pd.read_csv('final_quasar_catalogue.csv', sep=',', usecols=['MASS'],header=0,squeeze=True).to_numpy()
    for r in what_rows:
        y_point = [ya[r]]
        y_list = []
        for x in range(0,count_rows[r]):
            y_list += y_point
        y += y_list
    print('Magnitudes created')
    
    y = 10**np.array(y)
    width = np.max(y)-np.min(y)
    mean = np.mean(y)
    y = (y-mean)/(width)
    return X,y

# %%
for i in pd.read_csv('E:/catalogues/final_quasar_catalogue.csv', sep=',', header=0,squeeze=True).columns:
    print(i)
# Out:
# SDSS_NAME
# RA
# DEC
# THING_ID
# PLATE
# MJD
# FIBERID
# Z_VI
# Z_PIPE
# ERR_ZPIPE
# ZWARNING
# Z_PCA
# ERR_ZPCA
# PCA_QUAL
# Z_CIV
# Z_CIII
# Z_MGII
# SDSS_MORPHO
# BOSS_TARGET1
# ANCILLARY_TARGET1
# ANCILLARY_TARGET2
# EBOSS_TARGET0
# NSPEC_BOSS
# SDSS_DR7
# PLATE_DR7
# MJD_DR7
# FIBERID_DR7
# UNIFORM
# ALPHA_NU
# SNR_SPEC
# SNR_1700
# SNR_3000
# SNR_5150
# FWHM_CIV
# BHWHM_CIV
# RHWHM_CIV
# AMP_CIV
# REWE_CIV
# ERR_REWE_CIV
# FWHM_CIII
# BHWHM_CIII
# RHWHM_CIII
# AMP_CIII
# REWE_CIII
# ERR_REWE_CIII
# FWHM_MGII
# BHWHM_MGII
# RHWHM_MGII
# AMP_MGII
# REWE_MGII
# ERR_REWE_MGII
# BAL_FLAG_VI
# BI_CIV
# ERR_BI_CIV
# AI_CIV
# ERR_AI_CIV
# CHI2TROUGH
# NCIV_2000
# VMIN_CIV_2000
# VMAX_CIV_2000
# NCIV_450
# VMIN_CIV_450
# VMAX_CIV_450
# REW_SIIV
# REW_CIV
# REW_ALIII
# RUN_NUMBER
# PHOTO_MJD
# RERUN_NUMBER
# COL_NUMBER
# FIELD_NUMBER
# OBJ_ID
# MI
# DGMI
# HI_GAL
# VAR_MATCHED
# VAR_CHI2
# VAR_A
# VAR_GAMMA
# RASS_COUNTS
# RASS_COUNTS_SNR
# SDSS2ROSAT_SEP
# N_DETECTION_XMM
# FLUX02_12KEV_SGL
# ERR_FLUX02_12KEV_SGL
# FLUX02_2KEV
# ERR_FLUX02_2KEV
# FLUX2_12KEV
# ERR_FLUX2_12KEV
# FLUX02_12KEV
# ERR_FLUX02_12KEV
# LUM02_2KEV_SGL
# LUM05_2KEV
# LUM2_12KEV
# LUM02_2KEV
# LUMX2_10_UPPER
# SDSS2XMM_SEP
# GALEX_MATCHED
# FUV
# FUV_IVAR
# NUV
# NUV_IVAR
# JMAG
# ERR_JMAG
# JSNR
# JRDFLAG
# HMAG
# ERR_HMAG
# HSNR
# HRDFLAG
# KMAG
# ERR_KMAG
# KSNR
# KRDFLAG
# SDSS2MASS_SEP
# W1MAG
# ERR_W1MAG
# W1SNR
# W1CHI2
# W2MAG
# ERR_W2MAG
# W2SNR
# W2CHI2
# W3MAG
# ERR_W3MAG
# W3SNR
# W3CHI2
# W4MAG
# ERR_W4MAG
# W4SNR
# W4CHI2
# CC_FLAGS
# PH_FLAG
# SDSS2WISE_SEP
# UKIDSS_MATCHED
# YFLUX
# YFLUX_ERR
# JFLUX
# JFLUX_ERR
# HFLUX
# HFLUX_ERR
# KFLUX
# KFLUX_ERR
# FIRST_MATCHED
# FIRST_FLUX
# FIRST_SNR
# SDSS2FIRST_SEP
# UMAG
# GMAG
# RMAG
# IMAG
# ZMAG
# RADeg
# DECDeg
# z
# Mi
# L5100
# eL5100
# L3000
# eL3000
# L1350
# eL1350
# MBH_MgII
# MBH_CIV
# Lbol
# eLbol
# nEdd
# SECTORS
